# %% [markdown]
# ### En un segundo scrapeo ya teniendo las URLs de cada uno de los festivales. Accederé a cada URL y me traeré los datos completos de cada festival de música (nombre, lugar, latitud, longitud, estilos de música, artistas, etc...)

# %% [markdown]
# ## Importo la librerías necesarias para el Scrapping y almacenamiento/ tratamiento de los datos

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

import json
import numpy as np
from datetime import datetime

# %% [markdown]
# ## Inicializo el diccionario donde iré almacenando los datos para después crear el DataFrame

# %%
# Inicializo el diccionario

dicc_festivales = {
                    "festival": [],
                    "lugar": [],
                    "fecha_inicio": [],
                    "fecha_fin": [],
                    "duracion": [],
                    "cod_postal": [],
                    "latitud": [],
                    "longitud": [],
                    "provincia": [],
                    "localidad": [],
                    "gratuito": [],
                    "artistas": [],
                    "estilos": [],
                   }

# %% [markdown]
# Importo el archivo csv con las URL

# %%
lista_url = pd.read_csv(r"..\data\datos_scrapping\lista_url.csv", index_col="Unnamed: 0")
lista_url
# Out:
#                                                    url
# 0    https://fanmusicfest.com//content/lovin-ibiza-...
# 1    https://fanmusicfest.com//content/ims-dalt-vil...
# 2       https://fanmusicfest.com//content/darkmad-2023
# 3    https://fanmusicfest.com//content/tv-hardcore-...
# 4    https://fanmusicfest.com//content/valencia-flo...
# ..                                                 ...
# 139  https://fanmusicfest.com//content/valladolid-b...
# 140  https://fanmusicfest.com//content/carrion-rock...
# 141  https://fanmusicfest.com//content/wachina-wach...
# 142  https://fanmusicfest.com//content/black-sound-...
# 143  https://fanmusicfest.com//content/heavy-jaia-2023
#
# [545 rows x 1 columns]

# %%
url_list = list(lista_url["url"])
len(url_list)
# Out:
# 545

# %%
def get_data(lista_URL):

    ''' 
    Función que conecta con la página web para extraer los datos de cada uno de los festivales y la almacena en un diccionario

    input: Recibe una lista (lst) de las URLs para cada estilo de música
    output: Retorna una diccionario (dict) con la información recogida de cada uno de los festivales
    
    '''
    for url in lista_URL:

        try:
            response = requests.get(url)
            html = response.content
            soup = bs(html, "lxml")

            geoJson = soup.find_all("script", {"type": "application/ld+json"})
            nombre = soup.find_all("h1", {"class": "page-title mb-0 mr-xl-3 text-center text-xl-left"})[0].get_text()

            dicc_festivales["festival"].append(nombre)
            dicc_festivales["gratuito"].append(json.loads(geoJson[0].getText())["@graph"][0]["isAccessibleForFree"])
            dicc_festivales["lugar"].append(json.loads(geoJson[0].getText())["@graph"][0]["location"].get("name","sin nombre"))

            dicc_festivales["fecha_inicio"].append(json.loads(geoJson[0].getText())["@graph"][0]["startDate"])
            dia_inicio = pd.to_datetime(json.loads(geoJson[0].getText())["@graph"][0]["startDate"])

            dicc_festivales["fecha_fin"].append(json.loads(geoJson[0].getText())["@graph"][0]["endDate"])
            dia_fin = pd.to_datetime(json.loads(geoJson[0].getText())["@graph"][0]["endDate"])

            dicc_festivales["duracion"].append(int(str((dia_fin - dia_inicio)).split(" ")[0])+1)

            dicc_festivales["cod_postal"].append(json.loads(geoJson[0].getText())["@graph"][0]["location"]["address"].get("postalCode", "sin cod_postal"))
            dicc_festivales["latitud"].append(json.loads(geoJson[0].getText())["@graph"][0]["location"]["geo"].get("latitude","sin latitud"))
            dicc_festivales["longitud"].append(json.loads(geoJson[0].getText())["@graph"][0]["location"]["geo"].get("longitude","sin longitud"))
            dicc_festivales["provincia"].append(json.loads(geoJson[0].getText())["@graph"][0]["location"]["address"].get("addressRegion","sin provincia"))
            dicc_festivales["localidad"].append(json.loads(geoJson[0].getText())["@graph"][0]["location"]["address"].get("addressLocality", "sin localidad"))
                   
            lista_estilos = []
            estilos = soup.find_all("a", {"class": "text-lowercase"})
            for estilo in estilos:
                lista_estilos.append(estilo.get_text())
            else:
                lista_estilos.append("sin estilo")
            dicc_festivales["estilos"].append(lista_estilos)

            artistas = []
            campos_artistas = []
            for data in json.loads(geoJson[0].getText())["@graph"][0]:
                campos_artistas.append(data)                
            if "performer" in campos_artistas:
                for artista in json.loads(geoJson[0].getText())["@graph"][0]["performer"]:            
                    artistas.append(artista["name"])
                dicc_festivales["artistas"].append(artistas)
            else:
                dicc_festivales["artistas"].append("sin artistas")
                

        except:
            pass
 
    return dicc_festivales

# %%
get_data(url_list)
# Out:
# {'festival': ['Lovin Ibiza Festival 2023',
#   'IMS Dalt Vila 2023',
#   'DarkMAD 2023',
#   'Tv Hardcore Festival 2023',
#   'Valencia Flow Fest 2023',
#   'Ritmo Festival 2023',
#   'Festival Días de Campo 2023',
#   'Molan los 90 Zaragoza 2023',
#   'Love the 90’s Valencia 2023',
#   "Homenaje a la Ruta 90's & 2MIL Benidorm 2023",
#   'Sónar 2023',
#   'OFFSónar 2023',
#   'O Son do Camiño 2023',
#   'OffWeek Festival 2023',
#   'Animal Sound Festival 2023',
#   'Love the 90’s Madrid 2023',
#   'A Summer Story 2023',
#   "Love the Tuenti's 2023",
#   'Ultra Beach Costa del Sol 2023',
#   'Holika Festival 2023',
#   'Maudes Festival 2023',
#   'Weekend Beach Festival 2023',
#   "Homenaje a la Ruta 90's & 2MIL Valencia 2023",
#   'FIB 2023',
#   'Fan Futura Fest 2023',
#   'Monegros Desert Festival 2023',
#   'Loona Summer Festival 2023',
#   'Arenal Sound 2023',
#   'Dreambeach Festival 2023',
#   'Medusa Sun Beach Festival 2023',
#   'Aquasella 2023',
#   'The End of the World Festival 2023',
#   'Love the 90’s Alicante 2023',
#   'Parallel Festival 2023',
#   'Extremúsika 2023',
#   'WAN Festival 2023',
#   'Palma On Season Fest 2023',
#   'AbroadFest 2023',
#   'Snowdaze 2023',
#   'Iboga Rave Madrid 2023',
#   'Makinando Festival 2023',
#   'Primavera Festival Cáceres 2023',
#   'Sun & Snow Weekend 2023',
#   "Planet 90's & 00's Dance Festival 2023",
#   'Iboga Rave Valencia 2023',
#   'I Love Music Festival 2023',
#   'LEV 2023',
#   'Iruña Rock 2023',
#   'Iberojoven 2023',
#   'Zeid Fest 2023',
#   'Sound Isidro 2023',
#   'Iboga Rave Valencia 2023',
#   'El Festivalino de Pescueza 2023',
#   'La Cueva Music Festival 2023',
#   'Cruilla de Primavera 2023',
#   'Viña Rock 2023',
#   'Solazo Fest 2023',
#   'Boquerón Primavera Festival 2023',
#   'Valencia Flow Fest 2023',
#   'Womad Cáceres 2023',
#   'Marenostrum Fuengirola 2023',
#   'Ciruelas Music Festival 2023',
#   'Mallorca Live Festival 2023',
#   'Murmura Festival 2023',
#   'Rie&Go Music Fest 2023',
#   'El Festival de las Estrellas 2023',
#   'Ourensound Fest 2023',
#   'Murcia On 2023',
#   'Guadalajara Vive Fest 2023',
#   'Kannasur Festival 2023',
#   'Primavera Sound Barcelona 2023',
#   'Sabatic Fest 2023',
#   'Alameda Festival 2023',
#   'Primavera Sound Madrid 2023',
#   'Noches del Botánico 2023',
#   'Afro Blue Festival 2023',
#   'Área 12 2023',
#   "Embotona't Festival 2023",
#   'Icónica Fest 2023',
#   'O Son do Camiño 2023',
#   'Boombastic Festival Madrid 2023',
#   'Cabró Rock 2023',
#   'Starlite Marbella 2023',
#   'City Festival Huelva 2023',
#   'Boombastic Festival Canarias 2023',
#   'Open Festival Tomares 2023',
#   'Caleidoscopio Music Fest 2023',
#   "Reggaeton Beach Festival (Marina D'Or) 2023",
#   'Granada Latina Festival 2023',
#   'Música en Grande 2023',
#   'Guitar BCN 2023',
#   'Oasis Sound Festival 2023',
#   'Festival Río Babel 2023',
#   'Lagata Reggae Festival 2023',
#   'Festival Cueva de Nerja 2023',
#   'Metrópoli Gijón 2023',
#   'A la Sombra de Jano Music Festival 2023',
#   'Festival de la Porta Ferrada 2023',
#   'Concert Music Festival 2023',
#   'Canet Rock 2023',
#   'Bahía Sound 2023',
#   'Concerts de Vivers 2023',
#   'Sotogrande Music Festival 2023',
#   'Weekend Beach Festival 2023',
#   'Cruilla 2023',
#   'Bilbao BBK Live 2023',
#   'Mad Cool Festival 2023',
#   'Feslloc! 2023',
#   'Granca Live Fest 2023',
#   'Alterna Festival 2023',
#   'Pirineos Sur 2023',
#   'Isla Bonita Love Festival 2023',
#   'Festival Internacional do Mundo Celta de Ortigueira 2023',
#   'Alma Festival Jardins Pedralbes 2023',
#   'Pirata Beach Festival 2023',
#   'Boombastic Festival Asturias 2023',
#   'EtnoSur 2023',
#   'Acampada Jove 2023',
#   'Festival Sónica 2023',
#   'Zevra Festival 2023',
#   'Tío Pepe Festival 2023',
#   'LeturAlma 2023',
#   'Sons del Món 2023',
#   'Cabo de Plata 2023',
#   'Nits de Vivers 2023',
#   'Festival Jardins Terramar 2023',
#   'Fan Futura Fest 2023',
#   'Imagina Funk 2023',
#   'Arenal Sound 2023',
#   'The Juergas Rock Festival 2023',
#   "Arts d'Estiu 2023",
#   'Festiuet 2023',
#   'SonRías Baixas 2023',
#   'SOM Festival Castelló 2023',
#   'Boombastic Day Costa del Sol 2023',
#   'Cabaret Festival El Puerto de Santa María 2023',
#   'Rototom Sunsplash 2023',
#   'Boombastic Festival Alicante 2023',
#   'Rabolagartija Festival 2023',
#   'Mediterránea Festival 2023',
#   'Festival De La Luz 2023',
#   'Noches de la Maestranza 2023',
#   'GrimalRock 2023',
#   'Festival Millenni 2021 / 2022',
#   'Miranda Urban Festival 2023',
#   'Inverfest 2023',
#   'Gazpatxo Rock 2023',
#   '40 Minutu Rock 2023',
#   'Pirata Fallas 2023',
#   'Granada 100% Mujer 2023',
#   'Live Las Ventas 2023',
#   'Iboga Rave Madrid 2023',
#   'Senior Festival 2023',
#   'Alabordaje Fest 2023',
#   'Primavera Trompetera 2023',
#   'Minifestival de Música Independiente 2023',
#   'Madrid Popfest 2023',
#   'Horteralia Madrid 2023',
#   'Festival Ochentero Sierra de Cádiz 2023',
#   'La Noche de Cadena 100 (2023)',
#   'Polar Sound Festival 2023',
#   'B·Series 2023',
#   'Festival Strenes 2023',
#   'Lets Festival 2023',
#   'Sound Isidro 2023',
#   'Indiferente Festival 2023',
#   'Sansan Festival 2023',
#   'Microsonidos 2023',
#   'Barcelona Psych Fest 2023',
#   'Los 40 Primavera Pop 2023',
#   'Gijón Sound Festival 2023',
#   "Festes de Primavera L'Hospitalet 2023",
#   'Las Noches del Malecón 2023',
#   'Cruilla de Primavera 2023',
#   'Vibra Mahou Fest Gijón 2023',
#   'Festival Al-Andalus 2023',
#   'Festival Ebroclub 2023',
#   'FiV 2023',
#   'Warm Up Festival 2023',
#   'Hurra Romería 2023',
#   'VID Festival 2023',
#   'A la LLum de la Lluna 2023',
#   'Primavera Aspesuena 2023',
#   'Fa Ce La Fest 2023',
#   'Fiestas de Rivas 2023',
#   'Ritmo Festival 2023',
#   'Fulanita Fest 2023',
#   'Marenostrum Fuengirola 2023',
#   'Mallorca Live Festival 2023',
#   'Interestelar Sevilla 2023',
#   "Embassa't 2023",
#   'Murmura Festival 2023',
#   'Esmorga Fest 2023',
#   'Deleste Festival 2023',
#   'Oh, See! Fest 2023',
#   'Spring Festival 2023',
#   'Murcia On 2023',
#   'Guadalajara Vive Fest 2023',
#   'San Miguel Tribu Festival 2023',
#   'Lo Esencial Music Festival 2023',
#   'Morrison Fest 2023',
#   'Primavera Sound Barcelona 2023',
#   'Montgorock (MRK Xàbia Festival) 2023',
#   'Block Party Arganzuela 2023',
#   'Barbeira SeaSon Fest 2023',
#   'Primavera Sound Madrid 2023',
#   'Palencia Sonora 2023',
#   'Festival de Les Arts 2023',
#   'Sonidos Líquidos 2023 - Malvasía Volcánica Weekend',
#   'Noches del Botánico 2023',
#   'Área 12 2023',
#   'Sónar 2023',
#   'O Son do Camiño 2023',
#   'Magnífic Fest 2023',
#   'Festival De Los Sentidos 2023',
#   'Es Jardí 2023',
#   'Cosquín Rock España 2023',
#   'Love the 90’s Madrid 2023',
#   'El Bosque Sonoro 2023',
#   '101 Music Festival Costa del Sol 2023',
#   'Starlite Marbella 2023',
#   'Tomavistas 2023',
#   'Antorchas Festival 2023',
#   'City Festival Huelva 2023',
#   'Mugacu Fest 2023',
#   "Love the Tuenti's 2023",
#   'Zorrilla’s Fest 2023',
#   'My Fest Cantabria Infinita 2023',
#   'Música en Grande 2023',
#   'Guitar BCN 2023',
#   'Vida Festival 2023',
#   'Observatorio Festival 2023',
#   'León Vive Festival 2023',
#   'Conexión Valladolid 2023',
#   'Polifonik Sound 2023',
#   'Oasis Sound Festival 2023',
#   'Ojeando Festival 2023',
#   'Vive Nigrán 2023',
#   'Vesu Festival 2023',
#   'Festival de la Porta Ferrada 2023',
#   'Concert Music Festival 2023',
#   'Bahía Sound 2023',
#   'Concerts de Vivers 2023',
#   'Espazo Fest 2023',
#   'Sotogrande Music Festival 2023',
#   'Cruilla 2023',
#   'Bilbao BBK Live 2023',
#   'Mad Cool Festival 2023',
#   'Brisa Festival 2023',
#   'Planeta Sound 2023',
#   'Cabaret Festival Roquetas de Mar 2023',
#   'Dale Argentina Fest 2023',
#   'Isla Bonita Love Festival 2023',
#   'Alma Festival Jardins Pedralbes 2023',
#   'FIB 2023',
#   'PortAmérica 2023',
#   'Fárdelej Festival Rioja Live 2023',
#   'Cap Roig Festival 2023',
#   'Barranco Fest 2023',
#   'No Sin Música 2023',
#   'Atlantic Fest 2023',
#   'Sinsal Esencial SON Estrella Galicia 2023',
#   'Sons del Món 2023',
#   'Universal Music Festival 2023',
#   'Nits de Vivers 2023',
#   'Low Festival 2023',
#   'Impacto Fest 2023',
#   'MoboFest Music Festival 2023',
#   '17º Ribeira Sacra Festival 2023',
#   'Festival Jardins Terramar 2023',
#   'Fan Futura Fest 2023',
#   'Idilic Festival 2023',
#   'Morriña Festival 2023',
#   'Locos por la Música 2023 (Fuengirola)',
#   'Arenal Sound 2023',
#   'Cabaret Festival Fuengirola 2023',
#   'Santander Music 2023',
#   'Prestoso Fest 2023',
#   'Brizna Festival 2023',
#   'Festival Amante 2023',
#   'Luna Sur Festival 2023',
#   'Supersónica Festival 2023',
#   'Sonorama Ribera 2023',
#   'FiestoRon 2023',
#   'Vive la Feria Torrelavega 2023',
#   'Cabaret Festival El Puerto de Santa María 2023',
#   'Cooltural Fest 2023',
#   'SummerFest Cerdanya 2023',
#   'Mediterránea Festival 2023',
#   'Phe Festival 2023',
#   'Esférica Rioja Alavesa 2023',
#   'Sierra Nevada por Todo lo Alto 2023',
#   'CanelaParty 2023',
#   'Contempopránea 2023',
#   'Festival De La Luz 2023',
#   'Random Fest 2023',
#   'Ebrovisión 2023',
#   'Cala Mijas Festival 2023',
#   'Gigante Festival 2023',
#   'Poetas del Rock Cuenca 2023',
#   'Osa do Mar 2023',
#   'Natural Sonora 2023',
#   'Noches de la Maestranza 2023',
#   'Cabaret Festival Latino Sevilla 2023',
#   '1001 Músicas de la Alhambra (Septiembre en el Generalife) 2023',
#   'Cabaret Festival Mairena del Aljarafe 2023',
#   'Vive Latino Zaragoza 2023',
#   'Nachiños Fest 2023',
#   'Salamanca Vive Festival 2023',
#   'Festival La Plaza Santander 2023',
#   'Granada Sound 2023',
#   'Festival Actual 2023',
#   'Festival SantasPascuas 2022/2023',
#   'F.E.A Festival 2023 (10º Aniversario)',
#   'NEU! Festival 2022/2023',
#   'Benidorm Fest 2023',
#   'El Día de la Marmota 2023',
#   'Inverfest 2023',
#   'Emac. 2023',
#   'Palma On Season Fest 2023',
#   'Ferrish Fest 2023',
#   'Estaciones Sonoras 2023',
#   'Mallorca Live Nights 2022/2023',
#   'Boquerón Primavera Festival 2023',
#   'Fiestas de Rivas 2023',
#   'Urban Hood 2023',
#   'Ciruelas Music Festival 2023',
#   'Guadalajara Vive Fest 2023',
#   'Kannasur Festival 2023',
#   'Alameda Festival 2023',
#   'Share Festival Barcelona 2023',
#   'I Love Reggaeton Madrid 2023',
#   'Sónar 2023',
#   'O Son do Camiño 2023',
#   'Boombastic Festival Madrid 2023',
#   'Animal Sound Festival 2023',
#   'Oh My Gol! LaLiga Music Experience 2023',
#   'Boombastic Festival Canarias 2023',
#   'Open Festival Tomares 2023',
#   'Granada Latina Festival 2023',
#   'Sunsetland Festival 2023',
#   'My Fest Cantabria Infinita 2023',
#   'Big Sound Festival 2023',
#   'Holika Festival 2023',
#   'León Vive Festival 2023',
#   'Puro Latino Fest Sevilla 2023',
#   'Conexión Valladolid 2023',
#   'Oasis Sound Festival 2023',
#   'Festival Río Babel 2023',
#   'Puro Latino Fest Madrid 2023',
#   'Salinas Sound Festival 2023',
#   'Reggaeton Beach Festival (Tenerife) 2023',
#   'Reggaeton Beach Festival (Asturias) 2023',
#   'Bahía Sound 2023',
#   'Sotogrande Music Festival 2023',
#   'Weekend Beach Festival 2023',
#   'Reggaeton Beach Festival (Benidorm) 2023',
#   'Reggaeton Beach Festival (Marbella) 2023',
#   'Pirata Beach Festival 2023',
#   'Boombastic Festival Asturias 2023',
#   'Covaleda Fest 2023',
#   'Reggaeton Beach Festival (Mallorca) 2023',
#   'Latin Fest Valencia 2023',
#   'Zevra Festival 2023',
#   'Puro Latino Fest Torremolinos 2023',
#   'Reggaeton Beach Festival (Barcelona) 2023',
#   'Reggaeton Beach Festival (Madrid) 2023',
#   'Cabo de Plata 2023',
#   'Impacto Fest 2023',
#   'Fan Futura Fest 2023',
#   'Morriña Festival 2023',
#   'Reggaeton Beach Festival (Santander) 2023',
#   'Loona Summer Festival 2023',
#   'Arenal Sound 2023',
#   'Puro Latino Fest Cádiz 2023',
#   'SonRías Baixas 2023',
#   'Dreambeach Festival 2023',
#   'Vive la Feria Torrelavega 2023',
#   'Reggaeton Beach Festival (Galicia) 2023',
#   'Boombastic Day Costa del Sol 2023',
#   'Boombastic Festival Alicante 2023',
#   'Riverland Festival 2023',
#   'Negrita Music Festival 2023',
#   'Salamanca Vive Festival 2023',
#   'Cranc Festival 2023',
#   'Metro Urban Fest 2023',
#   'Madrid Salvaje 2023',
#   'Rocanrola Alicante 2023',
#   'Extremúsika 2023',
#   'Miranda Urban Festival 2023',
#   'Pirata Fallas 2023',
#   'La Noche de Cadena 100 (2023)',
#   'Primaverando Sevilla Festival 2023',
#   'Primavera Festival Cáceres 2023',
#   'Primavera Trompetera 2023',
#   'B·Series 2023',
#   'Los 40 Primavera Pop 2023',
#   'La Cueva Music Festival 2023',
#   'Las Noches del Malecón 2023',
#   'Solazo Fest 2023',
#   'Fuc! Festival Universitario Castellón 2023',
#   '40 Minutu Rock 2023',
#   'Pirata Fallas 2023',
#   'Heavy Metal Espectros 2023',
#   'A Candeloria 2023',
#   'Adictes Fest 2023',
#   'Palacio Metal Fest 2023',
#   'Devil´s Groove Metal Fest 2023',
#   'Euskal Metal Fest 2023',
#   'Puertollano Winter Festival 2023',
#   'Diario de un Metalhead Fest 2023',
#   'Pounding Metal Fest 2023',
#   'Iberian Southern Warriors Metal Fest 2023',
#   'Iberian Warriors Metal Fest 2023',
#   'Rebel Fest 2023',
#   'Alabordaje Fest 2023',
#   'Iruña Rock 2023',
#   'Festival Guoman 2023',
#   'Trincheras Rock 2023',
#   'Metalmeria 2023',
#   'Crápula a Go Go 2023',
#   'Microsonidos 2023',
#   'Barcelona Psych Fest 2023',
#   'Torrock Festival 2023',
#   'San Jorge Rock 2023',
#   'Me Dan Arkadas Fest 2023',
#   'Araba Distortion Fest 2023',
#   'Cachopo Fest 2023',
#   'Bbfest (Burgos Brass Fest) Primavera 2023',
#   'Southern Metal Fest 2023',
#   'Kalagurrirock 2023',
#   'Viña Rock 2023',
#   'Festival Ebroclub 2023',
#   'DarkMAD 2023',
#   "Desemboca Rock'n'Roll Festival 2023",
#   'Beach Riot Fest 2023',
#   'Volcano Fest 2023',
#   'Galia Metal Fest 2023',
#   'Vértigo Rock 2023',
#   'Zotes Rock 2023',
#   'Storm Metal Fest 2023',
#   'Cáceres Underground Weekend 2023',
#   'OrozkoRock 2023',
#   'No Future Fest 2023 (Vol.5)',
#   'Rocktabator Fest 2023',
#   'Víncula Rock 2023',
#   'Ourensound Fest 2023',
#   'Kristonfest 2023',
#   'Montgorock (MRK Xàbia Festival) 2023',
#   'Surf O Rama Festival 2023',
#   'Block Party Arganzuela 2023',
#   'Iberia Festival Murcia 2023',
#   'Chichotorment Fest 2023',
#   'Ehuneko Bat 2023',
#   'Z! Live Rock Fest 2023',
#   'Astudillo Punk Rock 2023',
#   'OleoRock 2023',
#   'Azkena Rock Festival 2023',
#   'Osteguna Rock Festival 2023',
#   'Renacer Metal Fest 2023',
#   'Festival Vintoro 2023',
#   'Kabiefest Metal 2023',
#   "HDC 843 Rockin' Fest 2023",
#   'Rock N Blues Festival 2023',
#   'Rock Imperium Festival 2023',
#   'The Wild Fest 2023',
#   'BBK Music Legends Festival 2023',
#   'Zeporock 2023',
#   'Koba Live 2023',
#   'Candil Rock 2023',
#   'Resurrection Fest 2023',
#   'Antifa Rock Juneda 2023',
#   'SubeRock 2023',
#   'VDB Rock 2023',
#   'Canet Rock 2023',
#   'Maizu Rock 2023',
#   'Psychobilly Meeting 2023',
#   'Mad Cool Festival 2023',
#   'Festival Blues Cazorla 2023',
#   'Zurbarán Rock 2023',
#   'Alterna Festival 2023',
#   'Mondra & Roll 2023',
#   'Galleta Rock Fest 2023',
#   'Dolmen Music Fest 2023',
#   'Pirata Beach Festival 2023',
#   'Motorbeach Festival 2023',
#   'Estaka Rock Festival 2023',
#   'Huercasa Country Festival 2023',
#   'Rock Land Art Fest 2023',
#   'Kanekas Metal Fest 2023',
#   'Tresparock 2023',
#   'Castelo Rock 2023',
#   'Tsunami Xixón Festival 2023',
#   'Enclave de Agua 2023',
#   'Ezca Fest 2023',
#   "Barna 'n' Roll 2023",
#   'Bellota Rock Fest 2023',
#   'Barcia Metal Fest 2023',
#   'Charca Rock 2023',
#   'The Juergas Rock Festival 2023',
#   'Festiuet 2023',
#   'Cebolla Rock 2023',
#   'ChooRock Festival 2023',
#   'Festival Novato Rock 2023',
#   'Leyendas del Rock 2023',
#   'FiestoRon 2023',
#   'Rock In Pino 2023',
#   'Frank Rock & Blues Festival 2023',
#   'Rabolagartija Festival 2023',
#   'AbejaRock 2023',
#   'Sierra Nevada por Todo lo Alto 2023',
#   'OchanduRock 2023',
#   'Unirock 2023',
#   'Ripollet Rock 2023',
#   'Rock en Femenino 2023',
#   'Poetas del Rock Cuenca 2023',
#   'GrimalRock 2023',
#   'Alpujarrako Fest 2023',
#   'Algarroba Rock Fest 2023',
#   'Beltane Fest 2023',
#   'Festival Revenidas 2023',
#   'BurGore Death Fest 2023',
#   'Inkestas Rock Festibal 2023',
#   'Karma Fest 2023',
#   'FestiJack 2023',
#   'Iberia Festival 2023',
#   'GinetaRock Festival 2023',
#   'Aquelarre Metalrock Fest 2023',
#   'Full Metal Holiday 2023 (Destination Mallorca)',
#   'Festardor 2023',
#   'Extremúsika 2023',
#   'Caravaca Power Pop 2023',
#   'Skulls Of Metal 2023',
#   'Festival Actual 2023',
#   'Gabonak In Hell 2023',
#   'F*ck The Censorship Festival 2023',
#   'Sant Antoni Pop Festival 2023',
#   'Rockin Race Jamboree 2023',
#   'Gazpatxo Rock 2023',
#   'Extreme Division Mallorca Fest 2023',
#   'Valladolid Blues 2023',
#   'Carrion Rock Festival 2023',
#   'Wáchina Wáchina Fest 2023',
#   'Black Sound Fest 2023',
#   'Heavy Jaia 2023'],
#  'lugar': ['Lío Ibiza',
#   ['Baluarte de Santa Lucía', 'Dalt Vila'],
#   'Autocine',
#   'Family Club',
#   'La 3 park',
#   'Paraje Natural Ermita de los Tres Juanes',
#   'Polideportivo Municipal',
#   'Parque Deportivo Ebro',
#   'Ciudad de Las Artes y Las Ciencias',
#   'Auditorio Julio Iglesias',
#   'Sónar de día - Fira Montjuïc',
#   'Poble Espanyol',
#   'Parque Monte Do Gozo',
#   'Parc del Fòrum',
#   'Recinto Ferial La Fica',
#   'IFEMA - Feria de Madrid',
#   'Ciudad del Rock',
#   'IFEMA. Feria de Madrid',
#   'Marenostrum Fuengirola',
#   '',
#   'IFEMA',
#   'Playa de Poniente',
#   'La Marina de Valencia',
#   'Benicàssim',
#   'Polideportivo San Javier',
#   'Desierto de los Monegros',
#   'Campo de Fútbol El Morche',
#   'Playa el Arenal',
#   'Playa de Villaricos (Cuevas del Almanzora)',
#   'Playa de Cullera',
#   'El Merediz',
#   'Parc de la Serra',
#   'Area 12 (Multiespacio Rabasa)',
#   'Port del Comte',
#   'Recinto Hípico',
#   'Cubierta de Leganés',
#   'Parc del Mar',
#   'Varias localizaciones',
#   'Estación de Candanchú',
#   'Sala La Riviera',
#   'Palacio de Congresos y Exposiciones de León',
#   'Recinto Hípico',
#   'Parque de actividades Mirlo Blanco',
#   'Music Park Torrijos',
#   'Sala Repvblicca',
#   'Siam Park',
#   'Laboral Ciudad de la Cultura',
#   'Navarra Arena',
#   'Recinto IberoJoven',
#   'BEC! Bizkaia Arena',
#   'Varias localizaciones',
#   'Sala Repvblicca',
#   'Plaza Mayor',
#   'Recinto Ferial de Alcalá de Guadaíra',
#   'Sala Apolo',
#   'Recinto Ferial de Villarrobledo',
#   'Recinto Ferial de Almería',
#   'Autocine Málaga Cesur FP',
#   'La 3 park',
#   'Plaza de San Jorge',
#   'Marenostrum Fuengirola',
#   'Campo de Fútbol de Valdivia',
#   'Recinto Mallorca Live (Antiguo Aqualand)',
#   'Varias ubicaciones',
#   'Parque el Ranchillo',
#   'Teatro Real',
#   'La Ciudad de los Muchachos',
#   'Plaza de Toros de Murcia',
#   'Fuente de la Niña',
#   'Pabellón de la Navegación',
#   'Parc del Fòrum',
#   'Autocine\xa0Málaga Cesur FP',
#   'Polígono La Amarguilla',
#   'Ciudad del Rock',
#   'UCM-Real Jardín Botánico Alfonso XIII',
#   'Jardines de Zuloaga',
#   'Multiespacio Rabasa',
#   'Poble Espanyol',
#   'La\xa0Plaza de España',
#   'Parque Monte Do Gozo',
#   'Auditorio Miguel Ríos',
#   'Zona deportiva de la UVic',
#   'Auditorio La Cantera de Nagüeles',
#   'Parque Alonso Sánchez',
#   'Anexo Estadio de Gran Canaria',
#   'Parque Jardines del Conde',
#   'Polideportivo Municipal El Jaenal',
#   "Marina d'Or",
#   'Cortijo del Conde',
#   'Campos del Malecón',
#   'Varias localizaciones',
#   'Recinto Oasis Sound',
#   'Caja Mágica',
#   'Azuara',
#   'Exterior Cueva de Nerja',
#   'Recinto Ferial Luis Adaro',
#   'Bárcena de Pie de Concha',
#   'Spai Port',
#   'Concert Music Festival',
#   'Canet de Mar',
#   'Centro Comercial Bahía Sur',
#   'Jardines del Real o Viveros',
#   'Santa María Polo Club',
#   'Playa de Poniente',
#   'Parc del Fòrum',
#   'Kobetamendi',
#   'La Ciudad de la Música',
#   'Poliesportiu de Benlloc',
#   'Estadio de Gran Canaria',
#   'Recinto Alterna Festival',
#   'Auditorio Natural de Lanuza',
#   'Puerto de Tazacorte',
#   'Plaza Isabel II',
#   'Poble Espanyol',
#   'Polígono Industrial Benieto',
#   'Jardines Feriales de Llanera',
#   'Recinto Etnosur',
#   "Sant Sadurní d'Anoia",
#   'Estadio Riomar',
#   'Playa de Cullera (Recinto Medusa Festival)',
#   'Bodegas Tío Pepe',
#   'Campo de Fútbol de Letur',
#   'Ciutadella de Roses',
#   'Playa de la Hierbabuena',
#   'Jardines del Real o Viveros',
#   'Parque Terramar',
#   'Polideportivo San Javier',
#   'Pozo Alcón',
#   'Playa el Arenal',
#   'Recinto The Juergas Rock',
#   "Espai Marítim ARTS d'Estiu",
#   'Playa de San Salvador',
#   'Recinto Multiusos da Estacada',
#   'Real Club Náutico de Castellón',
#   'Marenostrum Fuengirola',
#   'Real Plaza de Toros',
#   'Recinto de Festivales (Benicàssim)',
#   'Área 12',
#   'Polideportivo Municipal de Villena',
#   'Parc de la Festa',
#   'Boimorto',
#   'Plaza de Toros de La Maestranza',
#   'GrimalRock',
#   'Varias localizaciones',
#   'La Fábrica de Tornillos',
#   'Varias localizaciones',
#   'Patio Escuelas',
#   'Landako Gunea',
#   'Jardines de Viveros',
#   'Palacio Quinta Alegre',
#   'Plaza de Toros de Las Ventas',
#   'Sala La Riviera',
#   'Plaza de la Música',
#   'Pabellón De La Cantábrica',
#   'Circuito de Jerez',
#   'Casino de Hostafrancs',
#   'Sala Galileo Galilei',
#   'IFEMA',
#   'Plaza de toros cubierta de El Bosque',
#   'WiZink Center',
#   'Estación de Baqueira-Beret',
#   'La Nau',
#   'Teatro de Girona',
#   'Sala Salamandra',
#   'Varias localizaciones',
#   'Palacio de Festivales de Cantabria',
#   'Ciudad de los Festivales',
#   'Varias localizaciones',
#   'Sala Upload',
#   'WiZink Center',
#   'Varias localizaciones',
#   'La Farga',
#   'La Fica',
#   'Sala Apolo',
#   'Recinto Ferial Luis Adaro',
#   'Recinto Piscina Municipal',
#   'La Fábrica de Tornillos',
#   'Plaza de la Constitución',
#   'Recinto la Fica',
#   'Aceñas de Cabañales',
#   'Auditorio Municipal',
#   'Monasterio de Sant Miquel dels Reis',
#   'Auditorio Alfredo Kraus',
#   'Exterior Auditorio Gustavo Freire',
#   'Auditorio Miguel Ríos',
#   'Paraje Natural Ermita de los Tres Juanes',
#   'Marenostrum Fuengirola',
#   'Marenostrum Fuengirola',
#   'Recinto Mallorca Live (Antiguo Aqualand)',
#   'Centro Andaluz de Arte Contemporáneo',
#   'Amfiteatre Parc Catalunya (Sabadell)',
#   'Varias ubicaciones',
#   'Praza da Vila',
#   'Jardins de Vivers',
#   'Auditorio Municipal de Málaga',
#   'Multiespacio Rabasa',
#   'Plaza de Toros de Murcia',
#   'Fuente de la Niña',
#   'Jardines de La Parrala',
#   'Palacio Vistalegre Arena',
#   'Autocine de Madrid',
#   'Parc del Fòrum',
#   'Recinto La Fontana',
#   'Explanada Multiusos Madrid Rio',
#   'Parque da Palma',
#   'Ciudad del Rock',
#   'Parque del Sotillo',
#   'Ciudad de las Artes y las Ciencias de Valencia',
#   'Bodegas La Geria',
#   'UCM-Real Jardín Botánico Alfonso XIII',
#   'Multiespacio Rabasa',
#   'Sónar de día - Fira Montjuïc',
#   'Parque Monte Do Gozo',
#   'Recinte Firal "Les Firetes"',
#   'Recinto Ferial',
#   'Antiguo Aquapark de Càlvia',
#   'Marenostrum Fuengirola',
#   'IFEMA - Feria de Madrid',
#   'El Bosque Sonoro',
#   'Plaza de Toros de la Malagueta',
#   'Auditorio La Cantera de Nagüeles',
#   'Parque Enrique Tierno Galván',
#   'Recinto Ferial',
#   'Parque Alonso Sánchez',
#   'Ruinas de la Iglesia de San Pedro',
#   'IFEMA. Feria de Madrid',
#   'Plaza de la Universidad',
#   'Campos De Sport De El Sardinero',
#   'Campos del Malecón',
#   'Varias localizaciones',
#   'La Masia d’en Cabanyes',
#   'Auditorio Natural',
#   'Campo Hípico Municipal "El Parque"',
#   'Antigua Hípica',
#   'Recinto Ferial de Barbastro',
#   'Recinto Oasis Sound',
#   'Ojén',
#   'Campo de fútbol Lourido',
#   'Fábrica de Armas de la Vega',
#   'Spai Port',
#   'Concert Music Festival',
#   'Centro Comercial Bahía Sur',
#   'Jardines del Real o Viveros',
#   'Pazo de Cea',
#   'Santa María Polo Club',
#   'Parc del Fòrum',
#   'Kobetamendi',
#   'La Ciudad de la Música',
#   'Plaza de Toros de la Malagueta',
#   'Estadio Municipal Colomán Trabado',
#   'Plaza de Toros',
#   'Poble Espanyol',
#   'Puerto de Tazacorte',
#   'Poble Espanyol',
#   'Benicàssim',
#   'Fábrica Azucreira de Portas',
#   'Arnedo',
#   'Jardí Botànic de Cap Roig',
#   'Plaza de Toros de Fitero',
#   'Muelle Ciudad del Puerto de Cádiz',
#   'Playa de A Concha',
#   'Isla de San Simón',
#   'Ciutadella de Roses',
#   'Teatro Real',
#   'Jardines del Real o Viveros',
#   'Ciudad Deportiva Guillermo Amor',
#   'Las Ventas de Albares',
#   "Parc Municipal n'Hereveta",
#   'Parador de Monforte de Lemos',
#   'Parque Terramar',
#   'Polideportivo San Javier',
#   'Espai Masia Bas',
#   'Muelle de Batería',
#   'Marenostrum Fuengirola',
#   'Playa el Arenal',
#   'Marenostrum Fuengirola',
#   'Campa de La Magdalena',
#   'Las Bazaniellas',
#   'El Cubo de Rustik',
#   'Recinto Festival Amante (junto a campo de fútbol)',
#   'Marenostrum Fuengirola',
#   'Plaza Mayor',
#   'Recinto Ferial',
#   'Recinto Ferial de Arucas',
#   'Recinto Ferial La Lechera',
#   'Real Plaza de Toros',
#   'Feria de Almería',
#   'Camí de Sant Marc',
#   'Parc de la Festa',
#   'Estadio Municipal El Peñón',
#   'Bodegas Ysios',
#   'Plaza de Andalucía',
#   'Recinto Ferial de Torremolinos',
#   'Baluartes de San Blás',
#   'Boimorto',
#   ['Escenario Castillo Sohail', 'Marenostrum Fuengirola'],
#   'Varios Recintos',
#   'Recinto Cala Mijas',
#   'Huerta del Obispo',
#   'Estadio "La Fuensanta"',
#   'Praza do Concello',
#   'Campo de fútbol',
#   'Plaza de Toros de La Maestranza',
#   'Recinto Hípico',
#   'Teatro del Generalife',
#   'Recinto Hípico',
#   'Recinto Expo',
#   'As Cabazas',
#   'Espacio Más',
#   'Plaza de Toros de Santander',
#   'Cortijo del Conde',
#   'Riojafórum',
#   'Baluarte',
#   'La Capsa]',
#   'Varias localizaciones',
#   "Palacio de Deportes L'Illa de Benidorm",
#   'Centro Andaluz de Arte Contemporáneo',
#   'Varias localizaciones',
#   'Centro Municipal de Cultura "La Mercé"',
#   'Parc del Mar',
#   'Sala La Mirona',
#   'Patio Antiguo Colegio',
#   'Es Gremi',
#   'Autocine Málaga Cesur FP',
#   'Auditorio Miguel Ríos',
#   'Espacio Mas',
#   'Campo de Fútbol de Valdivia',
#   'Fuente de la Niña',
#   'Pabellón de la Navegación',
#   'Polígono La Amarguilla',
#   'Parc del Fòrum',
#   'IFEMA',
#   'Sónar de día - Fira Montjuïc',
#   'Parque Monte Do Gozo',
#   'Auditorio Miguel Ríos',
#   'Recinto Ferial La Fica',
#   'Estadio Cívitas Metropolitano',
#   'Anexo Estadio de Gran Canaria',
#   'Parque Jardines del Conde',
#   'Cortijo del Conde',
#   'Recinto Ferial - La Fica',
#   'Campos De Sport De El Sardinero',
#   'Ciudad de las Artes y las Ciencias',
#   '',
#   'Campo Hípico Municipal "El Parque"',
#   'Estadio Olímpico de La Cartuja',
#   'Antigua Hípica',
#   'Recinto Oasis Sound',
#   'Caja Mágica',
#   'Ciudad del Rock',
#   'Estadio Municipal Antonio Peroles',
#   'La Laguna',
#   'Centro Niemeyer',
#   'Centro Comercial Bahía Sur',
#   'Santa María Polo Club',
#   'Playa de Poniente',
#   'Estadio Municipal Guillermo Amor',
#   'Estadio Municipal San Pedro Alcántara',
#   'Polígono Industrial Benieto',
#   'Jardines Feriales de Llanera',
#   'Campamento Juvenil Raso de Nava',
#   'Poliesportiu Municipal Mateu Cañellas',
#   'Auditorio Marina Sur',
#   'Playa de Cullera (Recinto Medusa Festival)',
#   'Recinto Ferial de Torremolinos en Málaga',
#   'Playa del Forum',
#   'Recinto Ifema Valdebebas',
#   'Playa de la Hierbabuena',
#   'Las Ventas de Albares',
#   'Polideportivo San Javier',
#   'Muelle de Batería',
#   'Campa de la Magdalena',
#   'Campo de Fútbol El Morche',
#   'Playa el Arenal',
#   'Recinto Ferial de Las Banderas',
#   'Recinto Multiusos da Estacada',
#   'Playa de Villaricos (Cuevas del Almanzora)',
#   'Recinto Ferial La Lechera',
#   'Parque Industrial Porto do Molle',
#   'Marenostrum Fuengirola',
#   'Área 12',
#   'Recinto Riverland',
#   'Recinto Virgen del Mar',
#   'Espacio Más',
#   'Claustro del Cármen',
#   'Cuartel de Artillería',
#   'IFEMA Feria de Madrid',
#   'Espai Rabasa',
#   'Recinto Hípico',
#   'La Fábrica de Tornillos',
#   'Jardines de Viveros',
#   'WiZink Center',
#   'Estadio de la Cartuja',
#   'Recinto Hípico',
#   'Circuito de Jerez',
#   'La Nau',
#   'WiZink Center',
#   'Recinto Ferial de Alcalá de Guadaíra',
#   'La Fica',
#   'Recinto Ferial de Almería',
#   'Plaza de Toros de Castellón',
#   'Landako Gunea',
#   'Jardines de Viveros',
#   'Sala Spectrum',
#   'Pazo de Ferias y Congresos',
#   'Espai Mercat',
#   'Parque de Las Marismas',
#   'Factoria de So',
#   'C.C Larratxo',
#   'Pabellón Ferial "La Central"',
#   'Sala Gong',
#   'Sala Shoko Live',
#   'Sala La Petite',
#   'Urban Rock Concept',
#   'Sala Andén 56 (antigua Hangar)',
#   'Pabellón De La Cantábrica',
#   'Navarra Arena',
#   'Plaza de España',
#   'Recinto ferial "El Trinquete"',
#   'Berlín Social Club',
#   'Morticia Puffo',
#   'Varias localizaciones',
#   'Sala Upload',
#   'Plaza Mayor',
#   'Polideportivo Municipal',
#   'Local Asociación (MásMúsica)',
#   'Fernando Buesa Arena',
#   'Sala Even',
#   'Varias localizaciones',
#   'Gruta 77',
#   'Aparcamiento del Silo',
#   'Recinto Ferial de Villarrobledo',
#   'La Fábrica de Tornillos',
#   'Autocine',
#   'Sala Font del Ferro',
#   'Discoteca Ku',
#   'Aguere Cultural',
#   'Polideportivo Municipal',
#   'Ermua Antzokia',
#   'Zotes del Páramo',
#   'Sala Babel',
#   'Mastropiero Gastrobar y Jardín',
#   'Orozco',
#   'Sala la Mirona',
#   'Plaza de Toros de Lodosa',
#   'Campo de Fútbol',
#   'La Ciudad de los Muchachos',
#   'Sala La Paqui (Antigua BUT)',
#   'Recinto La Fontana',
#   'Sala Repvblicca',
#   'Explanada Multiusos Madrid Rio',
#   'Antiguo Cuartel de Artillería',
#   'Antugua Fábrica de Orujo',
#   'Bekosolo Parkea',
#   'Recinto Ferial de I.F.E.Z.A',
#   'Polideportivo La Joya',
#   'Polideportivo Matías Prats',
#   'Recinto Mendizabala',
#   'Plaza de la Virgen Blanca',
#   'Sala ReviLive',
#   'Plaza de Toros',
#   'Los Hoyos Bidea Iza',
#   'Parque de La Pollina',
#   'Recinto Las Arenas',
#   'Parque de la Cuesta del Batel',
#   'Parque Forestal San Miguel de Oia',
#   'Bilbao Arena',
#   'Albergue Dulcinea del Toboso',
#   'Koba-Live',
#   'Aparcamientos del Edificio Cultural Paseo del Generalife',
#   'Campo de fútbol de Celeiro',
#   'Recinto Antifa Rock Juneda',
#   'Pabellon Multiusos',
#   'Patio del instituto viejo',
#   'Canet de Mar',
#   'Intriago',
#   'Varias ubicaciones',
#   'La Ciudad de la Música',
#   'Cazorla (Varios espacios)',
#   'Parque de San Agustín',
#   'Recinto Alterna Festival',
#   'Parque de Monterrón',
#   'Ciudad Deportiva Alberto Fernández',
#   'Recinto del antiguo Liceo',
#   'Polígono Industrial Benieto',
#   'Playa Amogable',
#   'Polideportivo Palomares',
#   'Campo de Fútbol Municipal Las Delicias',
#   'Santo Domingo de la Calzada',
#   'Explanada Naves de Ojea',
#   'Trespaderne',
#   'Castelo Rock',
#   'Parque Hermanos Castro',
#   'Paraje natural Soto Playa',
#   'Real Fábrica de Ezcaray',
#   'Poble Espanyol',
#   'La Abadía',
#   'Auditorio Torres Oscuras',
#   'Auditorio Municipal',
#   'Recinto The Juergas Rock',
#   'Playa de San Salvador',
#   'Plaza de Toros de Belorado',
#   'Auditorio Municipal',
#   'Piscina Municipal',
#   'Polideportivo Municipal',
#   'Recinto Ferial de Arucas',
#   'Plaza Mayor',
#   'Auditorio Torres Oscuras',
#   'Polideportivo Municipal de Villena',
#   'Recinto Ferial de Béjar',
#   'Plaza de Andalucía',
#   'Pabellón de l@s Jóvenes',
#   'Varias localizaciones',
#   'Parc dels Pinetons',
#   'Polideportivo Matias Prats',
#   'Estadio "La Fuensanta"',
#   'GrimalRock',
#   'Explanada recinto ferial Dalías',
#   'Carpa Municipal Parque La Escalera',
#   'Polideportivo Municipal de Comillas',
#   'Porto de Vilaxoán',
#   'Sala Andén 56',
#   'Sopela',
#   'Parking Nuevo C/Pelayo',
#   'Plaza de Toros de Aranjuez',
#   'Auditorio Julio Iglesias',
#   'Salón Municipal',
#   'Garaje Beat Club',
#   'Hotel Iberostar Club Cala Barca',
#   'Puerto de Sagunto',
#   'Recinto Hípico',
#   'Caravaca de la Cruz',
#   'Recinto Ferial Cubierto',
#   'Riojafórum',
#   'Larratxo Kultur Etxea',
#   'Plaza de Toros',
#   'Pub Monkey',
#   'Auditorio Principe de Asturias',
#   'Patio Escuelas',
#   'Sala Es Gremi Centre Musical',
#   'Teatro Carrión',
#   'Sala Infinity',
#   '16 Toneladas',
#   'Teatro Imperial',
#   'Centro Cultural Larratxo'],
#  'fecha_inicio': ['2023-04-28',
#   '2023-04-28',
#   '2023-04-29',
#   '2023-04-29',
#   '2023-05-06',
#   '2023-05-12',
#   '2023-05-19',
#   '2023-05-20',
#   '2023-06-03',
#   '2023-06-10',
#   '2023-06-15',
#   '2023-06-15',
#   '2023-06-15',
#   '2023-06-16',
#   '2023-06-16',
#   '2023-06-17',
#   '2023-06-23',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-06-29',
#   '2023-06-30',
#   '2023-07-05',
#   '2023-07-08',
#   '2023-07-13',
#   '2023-07-28',
#   '2023-07-29',
#   '2023-07-29',
#   '2023-08-01',
#   '2023-08-09',
#   '2023-08-09',
#   '2023-08-17',
#   '2023-08-26',
#   '2023-08-26',
#   '2023-09-01',
#   '2023-10-12',
#   '2023-01-01',
#   '2023-02-10',
#   '2023-03-02',
#   '2023-03-17',
#   '2023-03-18',
#   '2023-03-25',
#   '2023-03-30',
#   '2023-03-31',
#   '2023-04-01',
#   '2023-04-01',
#   '2023-04-08',
#   '2023-04-27',
#   '2023-03-31',
#   '2023-04-01',
#   '2023-04-01',
#   '2023-04-01',
#   '2023-04-01',
#   '2023-04-14',
#   '2023-04-15',
#   '2023-03-10',
#   '2023-04-28',
#   '2023-04-28',
#   '2023-04-29',
#   '2023-05-06',
#   '2023-05-11',
#   '2023-05-13',
#   '2023-05-13',
#   '2023-05-18',
#   '2023-05-19',
#   '2023-05-19',
#   '2023-01-21',
#   '2023-05-26',
#   '2023-05-26',
#   '2023-05-26',
#   '2023-05-26',
#   '2023-06-01',
#   '2023-06-01',
#   '2023-06-02',
#   '2023-06-08',
#   '2023-06-09',
#   '2023-06-09',
#   '2023-06-10',
#   '2023-06-11',
#   '2023-06-15',
#   '2023-06-15',
#   '2023-06-16',
#   '2023-06-16',
#   '2023-06-21',
#   '2023-06-22',
#   '2023-06-23',
#   '2023-06-23',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-06-28',
#   '2023-01-27',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-05',
#   '2023-07-05',
#   '2023-07-06',
#   '2023-07-06',
#   '2023-07-06',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-08',
#   '2023-07-09',
#   '2023-07-10',
#   '2023-07-12',
#   '2023-07-13',
#   '2023-07-13',
#   '2023-07-13',
#   '2023-07-14',
#   '2023-07-21',
#   '2023-07-21',
#   '2023-07-21',
#   '2023-07-21',
#   '2023-07-26',
#   '2023-07-26',
#   '2023-07-28',
#   '2023-07-28',
#   '2023-07-28',
#   '2023-08-01',
#   '2023-08-02',
#   '2023-08-02',
#   '2023-08-03',
#   '2023-08-03',
#   '2023-08-04',
#   '2023-08-12',
#   '2023-08-15',
#   '2023-08-16',
#   '2023-08-17',
#   '2023-08-17',
#   '2023-08-18',
#   '2023-08-25',
#   '2023-09-01',
#   '2023-09-02',
#   '2021-10-02',
#   '2023-02-03',
#   '2023-01-06',
#   '2023-02-10',
#   '2023-02-25',
#   '2023-03-02',
#   '2023-03-11',
#   '2023-02-04',
#   '2023-03-18',
#   '2023-03-18',
#   '2023-03-25',
#   '2023-03-30',
#   '2023-02-25',
#   '2023-03-03',
#   '2023-03-18',
#   '2023-03-18',
#   '2023-03-18',
#   '2023-03-24',
#   '2023-02-25',
#   '2023-03-31',
#   '2023-03-03',
#   '2023-04-01',
#   '2023-04-01',
#   '2023-04-06',
#   '2023-02-03',
#   '2023-04-14',
#   '2023-04-14',
#   '2023-04-21',
#   '2023-04-21',
#   '2023-04-21',
#   '2023-03-10',
#   '2023-04-22',
#   '2023-04-22',
#   '2023-04-28',
#   '2023-04-28',
#   '2023-04-29',
#   '2023-04-29',
#   '2023-04-29',
#   '2023-05-05',
#   '2023-05-06',
#   '2023-05-11',
#   '2023-05-11',
#   '2023-05-12',
#   '2023-05-13',
#   '2023-05-13',
#   '2023-05-18',
#   '2023-05-19',
#   '2023-05-19',
#   '2023-05-19',
#   '2023-05-19',
#   '2023-05-19',
#   '2023-05-26',
#   '2023-05-26',
#   '2023-05-26',
#   '2023-05-26',
#   '2023-05-26',
#   '2023-05-26',
#   '2023-05-27',
#   '2023-06-01',
#   '2023-06-02',
#   '2023-06-03',
#   '2023-06-07',
#   '2023-06-08',
#   '2023-06-08',
#   '2023-06-09',
#   '2023-06-09',
#   '2023-06-09',
#   '2023-06-10',
#   '2023-06-15',
#   '2023-06-15',
#   '2023-06-15',
#   '2023-06-16',
#   '2023-06-16',
#   '2023-06-17',
#   '2023-06-17',
#   '2023-06-17',
#   '2023-06-17',
#   '2023-06-21',
#   '2023-06-22',
#   '2023-06-22',
#   '2023-06-22',
#   '2023-06-23',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-06-28',
#   '2023-01-27',
#   '2023-06-29',
#   '2023-06-29',
#   '2023-06-29',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-05',
#   '2023-07-06',
#   '2023-07-06',
#   '2023-07-06',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-08',
#   '2023-07-10',
#   '2023-07-13',
#   '2023-07-13',
#   '2023-07-14',
#   '2023-07-14',
#   '2023-07-20',
#   '2023-07-21',
#   '2023-07-21',
#   '2023-07-21',
#   '2023-07-21',
#   '2023-07-25',
#   '2023-07-26',
#   '2023-07-28',
#   '2023-07-28',
#   '2023-07-28',
#   '2023-07-28',
#   '2023-07-28',
#   '2023-07-28',
#   '2023-07-28',
#   '2023-07-28',
#   '2023-07-29',
#   '2023-08-01',
#   '2023-08-01',
#   '2023-08-03',
#   '2023-08-03',
#   '2023-08-04',
#   '2023-08-04',
#   '2023-08-05',
#   '2023-08-05',
#   '2023-08-09',
#   '2023-08-11',
#   '2023-08-11',
#   '2023-08-15',
#   '2023-08-17',
#   '2023-08-17',
#   '2023-08-18',
#   '2023-08-18',
#   '2023-08-18',
#   '2023-08-18',
#   '2023-08-23',
#   '2023-08-24',
#   '2023-08-25',
#   '2023-08-25',
#   '2023-08-31',
#   '2023-08-31',
#   '2023-08-31',
#   '2023-08-31',
#   '2023-09-01',
#   '2023-09-01',
#   '2023-09-01',
#   '2023-09-02',
#   '2023-09-02',
#   '2023-09-02',
#   '2023-09-08',
#   '2023-09-08',
#   '2023-09-08',
#   '2023-09-13',
#   '2023-09-15',
#   '2023-01-02',
#   '2023-01-07',
#   '2023-01-21',
#   '2022-11-26',
#   '2023-01-31',
#   '2023-02-04',
#   '2023-01-06',
#   '2023-02-10',
#   '2023-02-10',
#   '2023-02-18',
#   '2023-02-24',
#   '2022-09-10',
#   '2023-04-29',
#   '2023-05-11',
#   '2023-05-13',
#   '2023-05-13',
#   '2023-05-26',
#   '2023-05-26',
#   '2023-06-02',
#   '2023-06-09',
#   '2023-06-10',
#   '2023-06-15',
#   '2023-06-15',
#   '2023-06-16',
#   '2023-06-16',
#   '2023-06-16',
#   '2023-06-23',
#   '2023-06-23',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-06-29',
#   '2023-06-29',
#   '2023-06-29',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-05',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-12',
#   '2023-07-13',
#   '2023-07-13',
#   '2023-07-15',
#   '2023-07-15',
#   '2023-07-21',
#   '2023-07-21',
#   '2023-07-22',
#   '2023-07-22',
#   '2023-07-26',
#   '2023-07-28',
#   '2023-07-28',
#   '2023-07-28',
#   '2023-07-29',
#   '2023-07-29',
#   '2023-08-01',
#   '2023-08-03',
#   '2023-08-03',
#   '2023-08-09',
#   '2023-08-11',
#   '2023-08-12',
#   '2023-08-12',
#   '2023-08-17',
#   '2023-08-24',
#   '2023-09-01',
#   '2023-09-08',
#   '2023-09-21',
#   '2023-09-23',
#   '2023-09-29',
#   '2023-10-05',
#   '2023-10-12',
#   '2023-02-03',
#   '2023-03-02',
#   '2023-03-18',
#   '2023-03-25',
#   '2023-03-30',
#   '2023-03-30',
#   '2023-02-25',
#   '2023-04-14',
#   '2023-04-15',
#   '2023-04-21',
#   '2023-04-28',
#   '2023-04-28',
#   '2023-02-25',
#   '2023-03-02',
#   '2023-03-03',
#   '2023-03-04',
#   '2023-03-04',
#   '2023-03-04',
#   '2023-03-04',
#   '2023-03-10',
#   '2023-03-11',
#   '2023-03-12',
#   '2023-03-18',
#   '2023-03-24',
#   '2023-03-24',
#   '2023-03-25',
#   '2023-03-25',
#   '2023-03-31',
#   '2023-03-31',
#   '2023-04-01',
#   '2023-04-01',
#   '2023-04-06',
#   '2023-02-03',
#   '2023-04-14',
#   '2023-04-14',
#   '2023-04-15',
#   '2023-04-15',
#   '2023-04-15',
#   '2023-04-15',
#   '2023-04-21',
#   '2023-04-22',
#   '2023-04-22',
#   '2023-04-28',
#   '2023-04-28',
#   '2023-04-29',
#   '2023-04-29',
#   '2023-05-05',
#   '2023-05-06',
#   '2023-05-12',
#   '2023-05-12',
#   '2023-05-12',
#   '2023-05-13',
#   '2023-05-18',
#   '2023-05-19',
#   '2023-05-20',
#   '2023-05-20',
#   '2023-05-20',
#   '2023-05-26',
#   '2023-05-27',
#   '2023-06-02',
#   '2023-06-02',
#   '2023-06-03',
#   '2023-06-03',
#   '2023-06-03',
#   '2023-06-03',
#   '2023-06-07',
#   '2023-06-09',
#   '2023-06-10',
#   '2023-06-15',
#   '2023-06-15',
#   '2023-06-16',
#   '2023-06-16',
#   '2023-06-16',
#   '2023-06-16',
#   '2023-06-17',
#   '2023-06-23',
#   '2023-06-23',
#   '2023-06-23',
#   '2023-06-23',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-06-28',
#   '2023-06-29',
#   '2023-06-30',
#   '2023-06-30',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-04',
#   '2023-07-06',
#   '2023-07-06',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-07',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-12',
#   '2023-07-13',
#   '2023-07-14',
#   '2023-07-14',
#   '2023-07-14',
#   '2023-07-21',
#   '2023-07-21',
#   '2023-07-21',
#   '2023-07-27',
#   '2023-07-27',
#   '2023-07-28',
#   '2023-07-28',
#   '2023-07-28',
#   '2023-07-29',
#   '2023-07-29',
#   '2023-08-02',
#   '2023-08-03',
#   '2023-08-05',
#   '2023-08-05',
#   '2023-08-05',
#   '2023-08-09',
#   '2023-08-11',
#   '2023-08-11',
#   '2023-08-11',
#   '2023-08-17',
#   '2023-08-18',
#   '2023-08-18',
#   '2023-08-19',
#   '2023-08-19',
#   '2023-08-25',
#   '2023-08-26',
#   '2023-08-31',
#   '2023-09-02',
#   '2023-09-02',
#   '2023-09-02',
#   '2023-09-02',
#   '2023-09-07',
#   '2023-09-09',
#   '2023-09-15',
#   '2023-09-23',
#   '2023-09-23',
#   '2023-09-29',
#   '2023-09-30',
#   '2023-10-07',
#   '2023-10-09',
#   '2023-10-11',
#   '2023-10-12',
#   '2023-10-20',
#   '2023-10-21',
#   '2023-01-02',
#   '2023-01-14',
#   '2023-01-28',
#   '2023-01-28',
#   '2023-02-02',
#   '2023-02-10',
#   '2023-02-10',
#   '2023-02-10',
#   '2023-02-11',
#   '2023-02-18',
#   '2023-02-04',
#   '2023-02-25'],
#  'fecha_fin': ['2023-04-30',
#   '2023-04-28',
#   '2023-04-30',
#   '2023-04-29',
#   '2023-05-07',
#   '2023-05-13',
#   '2023-05-21',
#   '2023-05-20',
#   '2023-06-03',
#   '2023-06-10',
#   '2023-06-17',
#   '2023-06-18',
#   '2023-06-17',
#   '2023-06-17',
#   '2023-06-17',
#   '2023-06-17',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-16',
#   '2023-07-29',
#   '2023-07-29',
#   '2023-07-29',
#   '2023-08-06',
#   '2023-08-13',
#   '2023-08-14',
#   '2023-08-20',
#   '2023-08-26',
#   '2023-08-26',
#   '2023-09-03',
#   '2023-10-14',
#   '2023-01-01',
#   '2023-02-12',
#   '2023-03-11',
#   '2023-03-18',
#   '2023-03-18',
#   '2023-03-25',
#   '2023-03-30',
#   '2023-04-02',
#   '2023-04-01',
#   '2023-04-01',
#   '2023-04-08',
#   '2023-04-30',
#   '2023-04-01',
#   '2023-04-01',
#   '2023-04-01',
#   '2023-05-31',
#   '2023-04-01',
#   '2023-04-16',
#   '2023-04-15',
#   '2023-04-22',
#   '2023-04-30',
#   '2023-04-30',
#   '2023-04-29',
#   '2023-05-07',
#   '2023-05-14',
#   '2023-08-19',
#   '2023-05-13',
#   '2023-05-20',
#   '2023-05-21',
#   '2023-05-20',
#   '2023-05-25',
#   '2023-05-27',
#   '2023-10-14',
#   '2023-05-27',
#   '2023-05-28',
#   '2023-06-03',
#   '2023-09-15',
#   '2023-06-03',
#   '2023-06-10',
#   '2023-07-30',
#   '2023-06-10',
#   '2023-09-02',
#   '2023-06-11',
#   '2023-07-22',
#   '2023-06-17',
#   '2023-06-17',
#   '2023-06-17',
#   '2023-09-02',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-07-01',
#   '2023-06-24',
#   '2023-06-25',
#   '2023-06-24',
#   '2023-07-01',
#   '2023-06-29',
#   '2023-07-01',
#   '2023-07-02',
#   '2023-07-02',
#   '2023-08-12',
#   '2023-07-09',
#   '2023-07-01',
#   '2023-08-20',
#   '2023-08-31',
#   '2023-07-01',
#   '2023-08-19',
#   '2023-07-23',
#   '2023-09-15',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-29',
#   '2023-07-08',
#   '2023-07-16',
#   '2023-07-27',
#   '2023-07-15',
#   '2023-07-15',
#   '2023-07-16',
#   '2023-07-15',
#   '2023-07-15',
#   '2023-07-24',
#   '2023-08-14',
#   '2023-07-22',
#   '2023-08-07',
#   '2023-07-29',
#   '2023-08-05',
#   '2023-08-10',
#   '2023-07-29',
#   '2023-07-29',
#   '2023-08-06',
#   '2023-08-05',
#   '2023-08-14',
#   '2023-08-05',
#   '2023-08-05',
#   '2023-08-20',
#   '2023-08-12',
#   '2023-08-20',
#   '2023-08-22',
#   '2023-08-19',
#   '2023-08-19',
#   '2023-08-19',
#   '2023-08-27',
#   '2023-09-16',
#   '2023-09-02',
#   '2023-01-13',
#   '2023-02-04',
#   '2023-02-05',
#   '2023-02-11',
#   '2023-02-25',
#   '2023-03-02',
#   '2023-03-11',
#   '2023-03-18',
#   '2023-03-18',
#   '2023-03-19',
#   '2023-03-25',
#   '2023-04-01',
#   '2023-02-25',
#   '2023-03-04',
#   '2023-03-18',
#   '2023-03-18',
#   '2023-03-18',
#   '2023-03-25',
#   '2023-03-31',
#   '2023-05-13',
#   '2023-04-01',
#   '2023-05-31',
#   '2023-04-01',
#   '2023-04-08',
#   '2023-04-07',
#   '2023-04-15',
#   '2023-04-14',
#   '2023-04-23',
#   '2023-04-22',
#   '2023-09-16',
#   '2023-04-22',
#   '2023-04-22',
#   '2023-04-22',
#   '2023-04-29',
#   '2023-04-30',
#   '2023-04-30',
#   '2023-04-29',
#   '2023-04-29',
#   '2023-06-02',
#   '2023-05-06',
#   '2023-05-13',
#   '2023-05-13',
#   '2023-05-13',
#   '2023-05-13',
#   '2023-08-19',
#   '2023-05-20',
#   '2023-05-20',
#   '2023-05-20',
#   '2023-05-21',
#   '2023-05-20',
#   '2023-05-21',
#   '2023-05-27',
#   '2023-05-27',
#   '2023-10-14',
#   '2023-05-27',
#   '2023-05-28',
#   '2023-05-26',
#   '2023-05-27',
#   '2023-06-03',
#   '2023-06-03',
#   '2023-06-03',
#   '2023-06-11',
#   '2023-06-10',
#   '2023-06-11',
#   '2023-06-10',
#   '2023-06-10',
#   '2023-07-30',
#   '2023-09-02',
#   '2023-06-17',
#   '2023-06-17',
#   '2023-06-18',
#   '2023-06-18',
#   '2023-08-06',
#   '2023-06-17',
#   '2023-06-17',
#   '2023-06-25',
#   '2023-09-02',
#   '2023-09-02',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-06-25',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-07-01',
#   '2023-06-29',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-06-30',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-02',
#   '2023-08-20',
#   '2023-08-31',
#   '2023-08-19',
#   '2023-07-23',
#   '2023-08-31',
#   '2023-09-15',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-22',
#   '2023-07-09',
#   '2023-08-16',
#   '2023-07-11',
#   '2023-07-08',
#   '2023-07-27',
#   '2023-07-16',
#   '2023-07-15',
#   '2023-07-15',
#   '2023-08-19',
#   '2023-07-22',
#   '2023-07-22',
#   '2023-07-23',
#   '2023-07-23',
#   '2023-08-07',
#   '2023-07-30',
#   '2023-08-05',
#   '2023-07-30',
#   '2023-07-30',
#   '2023-07-29',
#   '2023-07-30',
#   '2023-08-10',
#   '2023-07-29',
#   '2023-07-29',
#   '2023-07-29',
#   '2023-07-29',
#   '2023-08-06',
#   '2023-08-31',
#   '2023-08-05',
#   '2023-08-05',
#   '2023-08-06',
#   '2023-08-06',
#   '2023-08-05',
#   '2023-08-06',
#   '2023-08-13',
#   '2023-08-12',
#   '2023-08-13',
#   '2023-08-20',
#   '2023-08-20',
#   '2023-08-25',
#   '2023-08-19',
#   '2023-08-19',
#   '2023-08-20',
#   '2023-08-19',
#   '2023-08-26',
#   '2023-08-26',
#   '2023-08-27',
#   '2023-08-25',
#   '2023-09-03',
#   '2023-09-02',
#   '2023-09-03',
#   '2023-08-31',
#   '2023-09-02',
#   '2023-09-02',
#   '2023-09-16',
#   '2023-09-14',
#   '2023-09-23',
#   '2023-09-30',
#   '2023-09-09',
#   '2023-09-09',
#   '2023-09-08',
#   '2023-09-17',
#   '2023-09-16',
#   '2023-01-07',
#   '2023-01-07',
#   '2023-01-21',
#   '2023-01-28',
#   '2023-02-04',
#   '2023-02-05',
#   '2023-02-05',
#   '2023-02-12',
#   '2023-02-12',
#   '2023-02-18',
#   '2023-09-30',
#   '2023-02-25',
#   '2023-04-29',
#   '2023-05-13',
#   '2023-05-13',
#   '2023-05-13',
#   '2023-05-27',
#   '2023-05-28',
#   '2023-06-03',
#   '2023-06-10',
#   '2023-06-10',
#   '2023-06-17',
#   '2023-06-17',
#   '2023-06-17',
#   '2023-06-17',
#   '2023-06-16',
#   '2023-06-24',
#   '2023-07-01',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-06-30',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-02',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-02',
#   '2023-07-02',
#   '2023-08-19',
#   '2023-09-15',
#   '2023-07-08',
#   '2023-07-09',
#   '2023-07-09',
#   '2023-07-15',
#   '2023-07-15',
#   '2023-07-15',
#   '2023-07-16',
#   '2023-07-15',
#   '2023-07-24',
#   '2023-07-22',
#   '2023-07-23',
#   '2023-07-23',
#   '2023-07-29',
#   '2023-07-30',
#   '2023-07-29',
#   '2023-07-29',
#   '2023-07-30',
#   '2023-07-29',
#   '2023-08-06',
#   '2023-08-05',
#   '2023-08-05',
#   '2023-08-13',
#   '2023-08-13',
#   '2023-08-13',
#   '2023-08-12',
#   '2023-08-19',
#   '2023-08-26',
#   '2023-09-02',
#   '2023-09-08',
#   '2023-09-24',
#   '2023-09-23',
#   '2023-09-30',
#   '2023-10-07',
#   '2023-10-14',
#   '2023-02-04',
#   '2023-03-02',
#   '2023-03-18',
#   '2023-03-25',
#   '2023-03-30',
#   '2023-04-01',
#   '2023-03-31',
#   '2023-04-14',
#   '2023-04-15',
#   '2023-09-16',
#   '2023-04-30',
#   '2023-04-28',
#   '2023-02-25',
#   '2023-03-02',
#   '2023-03-04',
#   '2023-03-04',
#   '2023-03-04',
#   '2023-03-04',
#   '2023-03-04',
#   '2023-03-11',
#   '2023-03-11',
#   '2023-03-12',
#   '2023-03-18',
#   '2023-03-25',
#   '2023-03-26',
#   '2023-03-25',
#   '2023-03-25',
#   '2023-04-01',
#   '2023-04-01',
#   '2023-04-01',
#   '2023-04-01',
#   '2023-04-09',
#   '2023-04-07',
#   '2023-04-15',
#   '2023-04-14',
#   '2023-04-15',
#   '2023-04-15',
#   '2023-04-15',
#   '2023-04-15',
#   '2023-04-21',
#   '2023-04-22',
#   '2023-04-22',
#   '2023-04-30',
#   '2023-04-29',
#   '2023-04-30',
#   '2023-04-30',
#   '2023-05-06',
#   '2023-05-06',
#   '2023-05-13',
#   '2023-05-13',
#   '2023-05-12',
#   '2023-05-13',
#   '2023-05-20',
#   '2023-05-20',
#   '2023-05-20',
#   '2023-05-20',
#   '2023-05-20',
#   '2023-05-27',
#   '2023-05-27',
#   '2023-06-03',
#   '2023-06-03',
#   '2023-06-03',
#   '2023-06-03',
#   '2023-06-03',
#   '2023-06-03',
#   '2023-06-10',
#   '2023-06-10',
#   '2023-06-10',
#   '2023-06-17',
#   '2023-06-15',
#   '2023-06-17',
#   '2023-06-17',
#   '2023-06-17',
#   '2023-06-18',
#   '2023-06-17',
#   '2023-06-25',
#   '2023-06-25',
#   '2023-06-24',
#   '2023-06-25',
#   '2023-06-24',
#   '2023-06-24',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-01',
#   '2023-07-11',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-08',
#   '2023-07-15',
#   '2023-07-16',
#   '2023-07-15',
#   '2023-07-15',
#   '2023-07-16',
#   '2023-07-22',
#   '2023-07-23',
#   '2023-07-22',
#   '2023-07-29',
#   '2023-07-29',
#   '2023-07-30',
#   '2023-07-29',
#   '2023-07-29',
#   '2023-07-29',
#   '2023-07-29',
#   '2023-08-05',
#   '2023-08-05',
#   '2023-08-05',
#   '2023-08-05',
#   '2023-08-05',
#   '2023-08-12',
#   '2023-08-12',
#   '2023-08-11',
#   '2023-08-13',
#   '2023-08-19',
#   '2023-08-19',
#   '2023-08-19',
#   '2023-08-19',
#   '2023-08-19',
#   '2023-08-25',
#   '2023-08-26',
#   '2023-08-31',
#   '2023-09-02',
#   '2023-09-02',
#   '2023-09-02',
#   '2023-09-02',
#   '2023-09-10',
#   '2023-09-09',
#   '2023-09-16',
#   '2023-09-23',
#   '2023-09-23',
#   '2023-09-30',
#   '2023-09-30',
#   '2023-10-07',
#   '2023-10-16',
#   '2023-10-14',
#   '2023-10-14',
#   '2023-10-21',
#   '2023-10-21',
#   '2023-01-07',
#   '2023-01-14',
#   '2023-01-28',
#   '2023-01-28',
#   '2023-02-05',
#   '2023-02-11',
#   '2023-02-10',
# ...
#   ['rock', 'indie', 'pop', 'folk', 'fusion', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'electronic', 'sin estilo'],
#   ['indie', 'urban', 'sin estilo'],
#   ['indie', 'indie pop', 'indie rock', 'sin estilo'],
#   ['indie', 'pop', 'sin estilo'],
#   ['rock', 'pop', 'singer-songwriter', 'sin estilo'],
#   ['indie', 'pop', 'electronic', 'hip-hop', 'urban', 'sin estilo'],
#   ['indie', 'pop', 'electronic', 'urban', 'sin estilo'],
#   ['indie', 'pop', 'urban', 'reggaeton', 'sin estilo'],
#   ['rock', 'pop', 'sin estilo'],
#   ['indie', 'pop', 'electronic', 'hip-hop', 'fusion', 'sin estilo'],
#   ['pop', 'fusion', 'sin estilo'],
#   ['indie', 'electronic', 'indie pop', 'indie rock', 'sin estilo'],
#   ['indie', 'indie pop', 'sin estilo'],
#   ['indie', 'pop', 'sin estilo'],
#   ['indie', 'pop', 'dj', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'sin estilo'],
#   ['indie', 'pop', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'alternative', 'sin estilo'],
#   ['rock', 'pop', 'sin estilo'],
#   ['pop', 'urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['pop', 'sin estilo'],
#   ['indie', 'indie pop', 'indie rock', 'sin estilo'],
#   ['pop', 'fusion', 'sin estilo'],
#   ['indie', 'pop', 'fusion', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'electronic', 'urban', 'sin estilo'],
#   ['indie pop', 'indie rock', 'indietronica', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'indie rock', 'sin estilo'],
#   ['indie',
#    'electronic',
#    'indie pop',
#    'indie rock',
#    'alternative',
#    'sin estilo'],
#   ['indie', 'indie pop', 'indie rock', 'sin estilo'],
#   ['rock', 'pop', 'folk', 'fusion', 'sin estilo'],
#   ['pop', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'sin estilo'],
#   ['indie', 'pop', 'electronic', 'alternative', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'sin estilo'],
#   ['rock', 'pop', 'fusion', 'sin estilo'],
#   ['indie', 'pop', 'sin estilo'],
#   ['indie', 'pop', 'dj', 'sin estilo'],
#   ['pop', 'singer-songwriter', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'hip-hop', 'folk', 'sin estilo'],
#   ['indie', 'pop', 'dj', 'sin estilo'],
#   ['indie', 'pop', 'urban', 'sin estilo'],
#   ['pop', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'electronic', 'indie pop', 'sin estilo'],
#   ['indie', 'pop', 'indie pop', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'electronic', 'rap', 'sin estilo'],
#   ['indie', 'dj', 'electro pop', 'sin estilo'],
#   ['indie', 'pop', 'folk', 'singer-songwriter', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'sin estilo'],
#   ['pop',
#    'indie pop',
#    'indie rock',
#    'alternative',
#    'rock n roll',
#    'sin estilo'],
#   ['rock', 'pop', 'folk', 'singer-songwriter', 'sin estilo'],
#   ['indie', 'electronic', 'sin estilo'],
#   ['electronic', 'indie pop', 'dj', 'indie rock', 'hip-hop', 'sin estilo'],
#   ['rock', 'indie', 'indie rock', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'sin estilo'],
#   ['indie', 'pop', 'sin estilo'],
#   ['pop', 'dj', 'urban', 'reggaeton', 'flamenco', 'sin estilo'],
#   ['indie', 'pop', 'hip-hop', 'rap', 'urban', 'sin estilo'],
#   ['hip-hop', 'urban', 'trap', 'sin estilo'],
#   ['hip-hop', 'rap', 'reggaeton', 'flamenco', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'hip-hop', 'urban', 'sin estilo'],
#   ['hip-hop', 'rumba', 'dancehall', 'sin estilo'],
#   ['fusion', 'rap', 'mestizaje', 'sin estilo'],
#   ['pop', 'hip-hop', 'fusion', 'rap', 'urban', 'sin estilo'],
#   ['latin', 'dance', 'reggaeton', 'sin estilo'],
#   ['electronic', 'dj', 'experimental', 'urban', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'electronic', 'indie pop', 'sin estilo'],
#   ['pop', 'electronic', 'hip-hop', 'urban', 'sin estilo'],
#   ['electronic', 'hip-hop', 'techno', 'house', 'rap', 'sin estilo'],
#   ['electronic', 'urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['pop', 'electronic', 'hip-hop', 'urban', 'sin estilo'],
#   ['pop', 'hip-hop', 'fusion', 'flamenco', 'sin estilo'],
#   ['urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['electronic', 'hip-hop', 'fusion', 'urban', 'latin', 'sin estilo'],
#   ['pop', 'rap', 'urban', 'latin', 'sin estilo'],
#   ['rap', 'urban', 'latin', 'trap', 'sin estilo'],
#   ['dj', 'hip-hop', 'techno', 'house', 'urban', 'sin estilo'],
#   ['indie', 'pop', 'hip-hop', 'urban', 'sin estilo'],
#   ['urban', 'latin', 'reggaeton', 'trap', 'sin estilo'],
#   ['indie', 'pop', 'hip-hop', 'urban', 'sin estilo'],
#   ['indie', 'pop', 'indie rock', 'urban', 'sin estilo'],
#   ['rock', 'pop', 'hip-hop', 'fusion', 'urban', 'sin estilo'],
#   ['urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['urban', 'reggaeton', 'trap', 'sin estilo'],
#   ['urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'hip-hop', 'urban', 'sin estilo'],
#   ['pop', 'urban', 'latin', 'flamenco', 'sin estilo'],
#   ['rock', 'pop', 'electronic', 'hip-hop', 'fusion', 'sin estilo'],
#   ['urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['rock', 'fusion', 'rap', 'urban', 'mestizaje', 'sin estilo'],
#   ['pop', 'electronic', 'hip-hop', 'urban', 'sin estilo'],
#   ['indie', 'pop', 'hip-hop', 'urban', 'trap', 'sin estilo'],
#   ['urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['urban', 'latin', 'reggaeton', 'trap', 'sin estilo'],
#   ['indie', 'pop', 'electronic', 'urban', 'reggaeton', 'sin estilo'],
#   ['urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['rock', 'hip-hop', 'fusion', 'rap', 'urban', 'sin estilo'],
#   ['indie', 'urban', 'sin estilo'],
#   ['indie', 'pop', 'electronic', 'hip-hop', 'urban', 'sin estilo'],
#   ['indie', 'pop', 'urban', 'reggaeton', 'sin estilo'],
#   ['urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['electronic', 'dj', 'urban', 'sin estilo'],
#   ['indie', 'pop', 'electronic', 'hip-hop', 'fusion', 'sin estilo'],
#   ['urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['rock', 'pop', 'fusion', 'rap', 'ska', 'sin estilo'],
#   ['electronic', 'hip-hop', 'techno', 'house', 'urban', 'sin estilo'],
#   ['pop', 'urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['pop', 'electronic', 'hip-hop', 'urban', 'sin estilo'],
#   ['pop', 'electronic', 'hip-hop', 'urban', 'sin estilo'],
#   ['pop', 'fusion', 'rap', 'urban', 'reggaeton', 'sin estilo'],
#   ['pop', 'electronic', 'dj', 'hip-hop', 'urban', 'sin estilo'],
#   ['indie', 'pop', 'urban', 'sin estilo'],
#   ['rock', 'indie', 'indie pop', 'dj', 'indie rock', 'sin estilo'],
#   ['hip-hop', 'rap', 'urban', 'trap', 'sin estilo'],
#   ['hip-hop', 'rap', 'urban', 'trap', 'sin estilo'],
#   ['hip-hop', 'rap', 'urban', 'sin estilo'],
#   ['rock', 'electronic', 'metal', 'punk', 'hip-hop', 'sin estilo'],
#   ['rock', 'punk', 'hip-hop', 'fusion', 'rap', 'sin estilo'],
#   ['rock', 'hip-hop', 'fusion', 'urban', 'mestizaje', 'sin estilo'],
#   ['pop', 'urban', 'sin estilo'],
#   ['electronic', 'dj', 'urban', 'reggaeton', 'sin estilo'],
#   ['electronic', 'dj', 'urban', 'electro', 'sin estilo'],
#   ['rock', 'fusion', 'rap', 'urban', 'reggae', 'sin estilo'],
#   ['rock', 'indie', 'electronic', 'alternative', 'hip-hop', 'sin estilo'],
#   ['pop', 'urban', 'latin', 'sin estilo'],
#   ['pop', 'electronic', 'urban', 'latin', 'sin estilo'],
#   ['indie', 'pop', 'urban', 'latin', 'reggaeton', 'sin estilo'],
#   ['dj', 'hip-hop', 'fusion', 'urban', 'latin', 'sin estilo'],
#   ['hip-hop', 'rap', 'urban', 'sin estilo'],
#   ['rock', 'punk', 'hip-hop', 'folk', 'ska', 'sin estilo'],
#   ['rock', 'hip-hop', 'fusion', 'urban', 'mestizaje', 'sin estilo'],
#   ['metal', 'heavy metal', 'speed metal', 'sin estilo'],
#   ['rock', 'punk', 'hip-hop', 'rap', 'ska', 'sin estilo'],
#   ['rock', 'punk', 'punk rock', 'sin estilo'],
#   ['metal', 'heavy metal', 'thrash metal', 'metalcore', 'sin estilo'],
#   ['metal', 'groove metal', 'sin estilo'],
#   ['metal', 'heavy metal', 'thrash metal', 'sin estilo'],
#   ['rock', 'pop', 'sin estilo'],
#   ['metal', 'heavy metal', 'power metal', 'sin estilo'],
#   ['metal', 'heavy metal', 'thrash metal', 'speed metal', 'sin estilo'],
#   ['metal', 'death metal', 'black metal', 'sin estilo'],
#   ['metal', 'folk', 'death metal', 'black metal', 'doom', 'sin estilo'],
#   ['rock', 'punk', 'punk rock', 'hardcore', 'sin estilo'],
#   ['rock', 'punk', 'fusion', 'punk rock', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'fusion', 'rap', 'sin estilo'],
#   ['rock', 'metal', 'sin estilo'],
#   ['rock', 'punk', 'punk rock', 'sin estilo'],
#   ['metal',
#    'heavy metal',
#    'thrash metal',
#    'death metal',
#    'grindcore',
#    'sin estilo'],
#   ['punk rock',
#    'rock n roll',
#    'garage rock',
#    'classic rock',
#    'rockabilly',
#    'sin estilo'],
#   ['rock', 'indie', 'pop', 'sin estilo'],
#   ['psychedelic', 'post-punk', 'shoegaze', 'krautrock', 'sin estilo'],
#   ['rock', 'punk', 'sin estilo'],
#   ['rock', 'punk', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'punk rock', 'hardcore', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'sin estilo'],
#   ['metal', 'heavy metal', 'power metal', 'sin estilo'],
#   ['rock', 'punk rock', 'ska', 'rhythm and blues', 'swing', 'sin estilo'],
#   ['rock', 'metal', 'stoner', 'groove metal', 'doom', 'sin estilo'],
#   ['rock', 'punk', 'rock urbano', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'hip-hop', 'rap', 'sin estilo'],
#   ['pop', 'soul', 'funk', 'garage', 'rhythm and blues', 'sin estilo'],
#   ['electro',
#    'post-punk',
#    'industrial',
#    'gothic metal',
#    'gothic rock',
#    'sin estilo'],
#   ['rock',
#    'punk',
#    'psychedelic',
#    'rhythm and blues',
#    'garage rock',
#    'sin estilo'],
#   ['rock', 'metal', 'punk', 'sin estilo'],
#   ['rock', 'metal', 'thrash metal', 'doom metal', 'sin estilo'],
#   ['rock',
#    'metal',
#    'heavy metal',
#    'power metal',
#    'symphonic metal',
#    'sin estilo'],
#   ['rock', 'metal', 'hardcore', 'sin estilo'],
#   ['rock', 'punk', 'sin estilo'],
#   ['rock',
#    'metal',
#    'heavy metal',
#    'hard rock',
#    'alternative rock',
#    'sin estilo'],
#   ['rock', 'punk rock', 'garage', 'rock n roll', 'surf', 'sin estilo'],
#   ['rock', 'alternative', 'hard rock', 'blues', 'post-rock', 'sin estilo'],
#   ['rock', 'punk', 'punk rock', 'sin estilo'],
#   ['punk', 'punk rock', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'punk rock', 'metalcore', 'sin estilo'],
#   ['rock', 'punk', 'folk', 'rap', 'ska', 'sin estilo'],
#   ['rock', 'metal', 'psychedelic', 'stoner', 'progressive', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'sin estilo'],
#   ['rock', 'rock n roll', 'rockabilly', 'surf', 'swing', 'sin estilo'],
#   ['rock', 'punk', 'indie rock', 'sin estilo'],
#   ['rock', 'pop', 'sin estilo'],
#   ['rock', 'metal', 'hardcore', 'nu metal', 'sin estilo'],
#   ['rock', 'punk', 'folk', 'punk rock', 'rock urbano', 'sin estilo'],
#   ['metal', 'heavy metal', 'power metal', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'rap', 'punk rock', 'sin estilo'],
#   ['rock', 'metal', 'folk', 'heavy metal', 'sin estilo'],
#   ['rock', 'metal', 'hard rock', 'blues', 'classic rock', 'sin estilo'],
#   ['rock', 'hard rock', 'garage rock', 'sin estilo'],
#   ['rock', 'metal', 'heavy metal', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'sin estilo'],
#   ['metal', 'heavy metal', 'power metal', 'sin estilo'],
#   ['rock', 'punk', 'rhythm and blues', 'rockabilly', 'surf', 'sin estilo'],
#   ['rock', 'blues', 'soul', 'sin estilo'],
#   ['metal', 'heavy metal', 'hard rock', 'death metal', 'sin estilo'],
#   ['rock', 'folk', 'sin estilo'],
#   ['rock', 'blues', 'soul', 'sin estilo'],
#   ['rock',
#    'hard rock',
#    'ska',
#    'rock n roll',
#    'rhythm and blues',
#    'sin estilo'],
#   ['metal', 'sin estilo'],
#   ['rock', 'hard rock', 'garage rock', 'classic rock', 'sin estilo'],
#   ['rock', 'metal', 'hardcore', 'death metal', 'metalcore', 'sin estilo'],
#   ['punk', 'punk rock', 'sin estilo'],
#   ['rock', 'pop', 'blues', 'soul', 'garage rock', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'ska', 'sin estilo'],
#   ['rock', 'indie', 'hip-hop', 'fusion', 'mestizaje', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'ska', 'hardcore', 'sin estilo'],
#   ['rock',
#    'punk rock',
#    'rock n roll',
#    'classic rock',
#    'rockabilly',
#    'sin estilo'],
#   ['rock', 'indie', 'pop', 'electronic', 'hip-hop', 'sin estilo'],
#   ['rock', 'blues', 'sin estilo'],
#   ['rock', 'metal', 'heavy metal', 'hard rock', 'sin estilo'],
#   ['rock', 'punk', 'fusion', 'rap', 'punk rock', 'sin estilo'],
#   ['punk', 'punk rock', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'sin estilo'],
#   ['rock', 'punk', 'hip-hop', 'punk rock', 'humor', 'sin estilo'],
#   ['rock', 'fusion', 'rap', 'urban', 'mestizaje', 'sin estilo'],
#   ['rock', 'punk', 'blues', 'soul', 'garage rock', 'sin estilo'],
#   ['rock', 'metal', 'sin estilo'],
#   ['country', 'alt-country', 'southern rock', 'bluegrass', 'sin estilo'],
#   ['rock', 'indie rock', 'alternative rock', 'sin estilo'],
#   ['rock', 'metal', 'metalcore', 'black metal', 'post-rock', 'sin estilo'],
#   ['rock', 'punk', 'punk rock', 'rock urbano', 'sin estilo'],
#   ['rock', 'punk', 'fusion', 'sin estilo'],
#   ['rock', 'metal', 'punk rock', 'hard rock', 'hardcore', 'sin estilo'],
#   ['hip-hop', 'reggae', 'blues', 'soul', 'funk', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'punk rock', 'sin estilo'],
#   ['rock', 'punk', 'punk rock', 'hardcore', 'sin estilo'],
#   ['punk', 'punk rock', 'sin estilo'],
#   ['rock', 'metal', 'sin estilo'],
#   ['rock', 'metal', 'heavy metal', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'hip-hop', 'fusion', 'sin estilo'],
#   ['rock', 'pop', 'hip-hop', 'fusion', 'punk rock', 'sin estilo'],
#   ['rock', 'punk', 'ska', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'heavy metal', 'punk rock', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'sin estilo'],
#   ['rock', 'metal', 'heavy metal', 'hard rock', 'thrash metal', 'sin estilo'],
#   ['rock', 'pop', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'ska', 'sin estilo'],
#   ['rock', 'blues', 'rock n roll', 'classic rock', 'sin estilo'],
#   ['rock', 'hip-hop', 'fusion', 'funk', 'flamenco', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'rap', 'punk rock', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'indie rock', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'ska', 'hardcore', 'sin estilo'],
#   ['rock', 'metal', 'hard rock', 'power metal', 'metalcore', 'sin estilo'],
#   ['rock', 'metal', 'hard rock', 'melodic metal', 'sin estilo'],
#   ['rock', 'metal', 'heavy metal', 'hard rock', 'sin estilo'],
#   ['rock', 'pop', 'fusion', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'fusion', 'heavy metal', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'sin estilo'],
#   ['metal', 'heavy metal', 'thrash metal', 'folk metal', 'sin estilo'],
#   ['rock', 'punk', 'rap', 'ska', 'sin estilo'],
#   ['rock', 'punk', 'fusion', 'rap', 'latin', 'sin estilo'],
#   ['metal',
#    'thrash metal',
#    'death metal',
#    'black metal',
#    'grindcore',
#    'sin estilo'],
#   ['metal', 'sin estilo'],
#   ['metal', 'folk', 'heavy metal', 'metalcore', 'industrial', 'sin estilo'],
#   ['rock', 'pop', 'metal', 'ska', 'funk', 'sin estilo'],
#   ['rock', 'pop', 'sin estilo'],
#   ['rock', 'metal', 'sin estilo'],
#   ['metal',
#    'alternative',
#    'heavy metal',
#    'death metal',
#    'metalcore',
#    'sin estilo'],
#   ['rock', 'metal', 'heavy metal', 'hard rock', 'thrash metal', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'hip-hop', 'sin estilo'],
#   ['rock', 'electronic', 'metal', 'punk', 'hip-hop', 'sin estilo'],
#   ['rock', 'indie', 'pop', 'power pop', 'mod', 'sin estilo'],
#   ['rock', 'metal', 'heavy metal', 'death metal', 'doom', 'sin estilo'],
#   ['indie', 'pop', 'indie pop', 'sin estilo'],
#   ['rock', 'metal', 'heavy metal', 'symphonic metal', 'sin estilo'],
#   ['rock', 'metal', 'punk', 'punk rock', 'rock urbano', 'sin estilo'],
#   ['rock', 'garage', 'rock n roll', 'sin estilo'],
#   ['rock', 'rhythm and blues', 'rockabilly', 'country', 'swing', 'sin estilo'],
#   ['rock', 'punk', 'hip-hop', 'ska', 'sin estilo'],
#   ['metal',
#    'thrash metal',
#    'grindcore',
#    'doom metal',
#    'melodic death metal',
#    'sin estilo'],
#   ['blues', 'sin estilo'],
#   ['rock', 'metal', 'heavy metal', 'sin estilo'],
#   ['punk rock', 'rock n roll', 'garage rock', 'sin estilo'],
#   ['rock', 'blues', 'sin estilo'],
#   ['metal', 'heavy metal', 'power metal', 'sin estilo']]}

# %% [markdown]
# Compruebo que todos los campos tienen la misma longitud para poder crear el dataframe

# %%
for key, value in dicc_festivales.items():
    print(key, len(value))
# Out:
# festival 545
# lugar 545
# fecha_inicio 545
# fecha_fin 545
# duracion 545
# cod_postal 545
# latitud 545
# longitud 545
# provincia 545
# localidad 545
# gratuito 545
# artistas 545
# estilos 545

# %% [markdown]
# Creo el dataframe

# %%
df_festivales = pd.DataFrame(dicc_festivales)
df_festivales
# Out:
#                        festival                                 lugar  \
# 0     Lovin Ibiza Festival 2023                             Lío Ibiza
# 1            IMS Dalt Vila 2023  [Baluarte de Santa Lucía, Dalt Vila]
# 2                  DarkMAD 2023                              Autocine
# 3     Tv Hardcore Festival 2023                           Family Club
# 4       Valencia Flow Fest 2023                             La 3 park
# ..                          ...                                   ...
# 540       Valladolid Blues 2023                        Teatro Carrión
# 541  Carrion Rock Festival 2023                         Sala Infinity
# 542   Wáchina Wáchina Fest 2023                          16 Toneladas
# 543       Black Sound Fest 2023                       Teatro Imperial
# 544             Heavy Jaia 2023              Centro Cultural Larratxo
#
#     fecha_inicio   fecha_fin  duracion cod_postal    latitud   longitud  \
# 0     2023-04-28  2023-04-30         3      07800  38.913852   1.443275
# 1     2023-04-28  2023-04-28         1      07800  38.908434   1.438789
# 2     2023-04-29  2023-04-30         2      28034  40.486224  -3.677802
# 3     2023-04-29  2023-04-29         1      45100   0.000000   0.000000
# 4     2023-05-06  2023-05-07         2      46012  39.410957  -0.334871
# ..           ...         ...       ...        ...        ...        ...
# 540   2023-02-10  2023-03-10        29      47001  41.649996  -4.728177
# 541   2023-02-11  2023-02-11         1      34004  42.006608  -4.519082
# 542   2023-02-18  2023-02-18         1      46009  39.481255  -0.387633
# 543   2023-02-04  2023-02-25        22      06400  38.953452  -5.860906
# 544   2023-02-25  2023-02-25         1      20017  43.315311  -1.938765
#
#           provincia   localidad gratuito  \
# 0    Islas Baleares     Eivissa    False
# 1    Islas Baleares       Ibiza    False
# 2            Madrid      Madrid    False
# 3            Toledo     Sonseca    False
# 4          Valencia      Pinedo    False
# ..              ...         ...      ...
# 540      Valladolid  Valladolid    False
# 541        Palencia    Palencia    False
# 542        Valencia    Valencia    False
# 543         Badajoz  Don Benito    False
# 544       Guipuzcoa    Donostia    False
#
#                                               artistas  \
# 0                                         sin artistas
# 1    [CamelPhat, Ida Engberg, Kölsch, Pete Tong, AN...
# 2    [The Human League, Ana Curra, Blac Kolor, Pink...
# 3    [Hardsuel, Pawlowski, DXPE, Dvrk Oktopus, Emei...
# 4    [Ojete Calor, Mueveloreina, Rocío Sáiz, Kika L...
# ..                                                 ...
# 540  [Martín Burguez Trío, Mingo Balaguer, Travelli...
# 541                       [Guadaña, Ciclón, Invadeath]
# 542  [The Mourning After, The Mocks, MOOON, The Cou...
# 543  [Vargas Blues Band, Gonzalo Portugal, The Flam...
# 544             [Serious Black, Blast Wave, Lethargus]
#
#                                                estilos
# 0                      [dj, techno, house, sin estilo]
# 1       [electronic, techno, house, dance, sin estilo]
# 2    [electro, post-punk, industrial, gothic metal,...
# 3            [techno, hardcore, hardstyle, sin estilo]
# 4         [pop, electronic, techno, house, sin estilo]
# ..                                                 ...
# 540                                [blues, sin estilo]
# 541             [rock, metal, heavy metal, sin estilo]
# 542  [punk rock, rock n roll, garage rock, sin estilo]
# 543                          [rock, blues, sin estilo]
# 544      [metal, heavy metal, power metal, sin estilo]
#
# [545 rows x 13 columns]

# %% [markdown]
# Exporto a csv para realizar un posterior análisis

# %%
df_festivales.to_csv(f"..\data\datos_demograficos\df_festivales_{len(df_festivales)}.csv", encoding= "utf16")
